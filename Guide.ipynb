# %%
from MyPackages import BIS_CBPR

# %%
#All Available Central Bank Policy Rates:
BIS_CBPR.CentralBankPolicyRates()
# Out:
# {'United States': {'Frequency': 'Daily',
#   'Country': 'United States',
#   'Country Code': 'US',
#   'Title': 'Central bank policy rates, United States',
#   'Unit': 'Per cent per year',
#   'Start Date': '1954-07-01',
#   'end_date': '2025-01-28',
#   'End Value': '4.375',
#   'End Value Status': 'Normal value',
#   'Last Updated': '2025-01-29T06:51:38.742Z'},
#  'United Kingdom': {'Frequency': 'Daily',
#   'Country': 'United Kingdom',
#   'Country Code': 'GB',
#   'Title': 'Central bank policy rates, United Kingdom',
#   'Unit': 'Per cent per year',
#   'Start Date': '1946-01-01',
#   'end_date': '2025-01-27',
#   'End Value': '4.75',
#   'End Value Status': 'Normal value',
#   'Last Updated': '2025-01-29T06:51:38.742Z'},
#  'Türkiye': {'Frequency': 'Daily',
#   'Country': 'Türkiye',
#   'Country Code': 'TR',
#   'Title': 'Central bank policy rates, Türkiye',
#   'Unit': 'Per cent per year',
#   'Start Date': '2002-02-20',
#   'end_date': '2025-01-24',
#   'End Value': '45.0',
# ...

# %%
 # All available countries/ regions:
list(BIS_CBPR.CentralBankPolicyRates().keys())
# Out:
# ['United States',
#  'United Kingdom',
#  'Türkiye',
#  'Thailand',
#  'Switzerland',
#  'Sweden',
#  'South Africa',
#  'Serbia',
#  'Saudi Arabia',
#  'Russia',
#  'Romania',
#  'Poland',
#  'Philippines',
#  'Peru',
#  'Norway',
#  'North Macedonia',
#  'New Zealand',
#  'Morocco',
#  'Mexico',
#  'Malaysia',
#  'Korea',
#  'Japan',
#  'Israel',
#  'Indonesia',
#  'India',
#  'Iceland',
#  'Hungary',
#  'Hong Kong SAR',
#  'Euro area',
#  'Denmark',
#  'Czechia',
#  'Croatia',
#  'Colombia',
#  'China',
#  'Chile',
#  'Canada',
#  'Brazil',
#  'Australia',
#  'Argentina']

# %%
#Central Bank Policy Rates for a specific country:
BIS_CBPR.CentralBankPolicyRates('United States')
# Out:
# 0.04375
